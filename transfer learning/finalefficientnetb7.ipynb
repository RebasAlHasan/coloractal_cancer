# %% [markdown]
# THE FOLLOWING STEPS ARE INVOLVED IN THE ENTIRE PROCESS OF IMAGE CLASSIFICATION
#
# 1.IMPORTING LIBRARIES
#
# 2.IMAGE PROCESSING
#
# 3.MODEL CREATION
#
# 4.MODEL COMPILATION
#
# 5.MODEL TRAINING
#
# 6.MODEL EVALUATION
#
# 7.MODEL PREDICTION

# %% [markdown]
# STEP 1-importing essential libraries
# tensorflow is a deep learning framework suitable for applications involving neural networks.
#
# using tensorflow we can build,train,evaluate and predict our neural network.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.metrics import roc_curve, auc
from itertools import cycle
from sklearn.preprocessing import label_binarize

# %% [markdown]
# # loading the dataset
# The training, testing and validation datasets are taken from the given dataset.

# %%
train_set='../input/curated-colon-dataset-for-deep-learning/train'
val_set='../input/curated-colon-dataset-for-deep-learning/val'
test_set='../input/curated-colon-dataset-for-deep-learning/test'

# %% [markdown]
# # STEP 2-image processing
# the imagedatagenerator is used to implement data augmentation. we can process the image as we want and create batches of image data.
#
# check this link for further details:- https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=20,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
validation_datagen = image.ImageDataGenerator()
test_datagen = image.ImageDataGenerator()

# %% [markdown]
# The images in digital world have pixels whose intensities range from 0 to 255 where black being 0 and white being 255.The rescaling of 1./255 allows it to convert to decimals values ranging from 0 to 1.
#
# the flow_from_directory allow us to use the images availabe in the google colab files section. the dataset contains images of variable size. hence it is essential to reshape them to (224,224). (the input dimensions for pretrained model)
#
# the batch size is an important parameter which can affect the training time and accuracy. less batch size increases accuracy and training time and vice versa. the batch size is taken as powers of two.

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    val_set,
    target_size=(224, 224),
    batch_size=16,
    shuffle=True,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'0_normal': 0, '1_ulcerative_colitis': 1, '2_polyps': 2, '3_esophagitis': 3}

# %% [markdown]
# # STEP 3-model creation
# we are using the pretrained cnn meaning that the cnn is already trained on the imagenet dataset and has the weights stored in it. we are going to customise the model by adding additional layers of our choice(remember more layers can increase parameters leading to overfitting).
#
# we are using the MobileNetV2 model for this application. this model was developed by google in 2017 and is known for its light memory. this model is ideal for devices with less RAM and processing power like microcomputers and mobiles.
#
# input_shape=(224,224,3) => this is the input dimensions of the model. this is the parameter mentioned in the processing part. the 3 refers to the three channels R,G,B
#
# we are training it partially so as to reduce the traning time on the stake of accuracy. (it is better to train model fully for better results)

# %% [markdown]
# > **NOTE- turn on the internet in the settings option in order to download the base model**

# %%
class CustomGaussianNoise(tf.keras.layers.GaussianNoise):
    def __init__(self, stddev, **kwargs):
        super(CustomGaussianNoise, self).__init__(stddev, **kwargs)

    def get_config(self):
        config = super().get_config()
        config.update({"stddev": self.stddev})
        return config
# Custom GaussianNoise layer with get_config method

# %%
base_model =tf.keras.applications.EfficientNetB7(weights='imagenet', input_shape=(224, 224, 3), include_top=False)

for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model)
model.add(CustomGaussianNoise(0.35))
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(CustomGaussianNoise(0.35))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 7s 0us/step
# 258088960/258076736 [==============================] - 7s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb7 (Functional)  (None, 7, 7, 2560)        64097687
# _________________________________________________________________
# custom_gaussian_noise (Custo (None, 7, 7, 2560)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2560)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               655616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# custom_gaussian_noise_1 (Cus (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 64,755,355
# Trainable params: 657,156
# Non-trainable params: 64,098,199
# _________________________________________________________________

# %% [markdown]
# # Model Compilation
# The built neural network has to be compiled before training. It is compiled using a loss function, optimizer and metrics. Here, crossentropy loss function, adam optimizer and accuracy, precision, recall and AUC are the different metrics.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 'Precision', 'Recall', 'AUC'])

# %% [markdown]
# ** Callbacks**

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# %% [markdown]
# # Model Training

# %% [markdown]
# TIP- ensure that the gpu (Graphics Processing Unit) is used so as to boost the training speed.

# %%
# Train model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 174s 741ms/step - loss: 5.2384 - accuracy: 0.7631 - precision: 0.7912 - recall: 0.7437 - auc: 0.9299 - val_loss: 4.7612 - val_accuracy: 0.9075 - val_precision: 0.9459 - val_recall: 0.8390 - val_auc: 0.9868
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/30
# 200/200 [==============================] - 105s 523ms/step - loss: 4.6117 - accuracy: 0.8813 - precision: 0.8904 - recall: 0.8731 - auc: 0.9776 - val_loss: 4.3202 - val_accuracy: 0.9300 - val_precision: 0.9387 - val_recall: 0.9180 - val_auc: 0.9922
# 200/200 [==============================] - 105s 525ms/step - loss: 4.2443 - accuracy: 0.9031 - precision: 0.9105 - recall: 0.9000 - auc: 0.9841 - val_loss: 3.9563 - val_accuracy: 0.9460 - val_precision: 0.9471 - val_recall: 0.9405 - val_auc: 0.9959
# Epoch 4/30
# 200/200 [==============================] - 106s 531ms/step - loss: 3.9089 - accuracy: 0.9159 - precision: 0.9229 - recall: 0.9094 - auc: 0.9871 - val_loss: 3.6779 - val_accuracy: 0.9380 - val_precision: 0.9416 - val_recall: 0.9345 - val_auc: 0.9950
# Epoch 5/30
# 200/200 [==============================] - 104s 520ms/step - loss: 3.5630 - accuracy: 0.9356 - precision: 0.9407 - recall: 0.9322 - auc: 0.9920 - val_loss: 3.3680 - val_accuracy: 0.9495 - val_precision: 0.9511 - val_recall: 0.9440 - val_auc: 0.9957
# Epoch 6/30
# 200/200 [==============================] - 106s 528ms/step - loss: 3.2757 - accuracy: 0.9381 - precision: 0.9421 - recall: 0.9356 - auc: 0.9923 - val_loss: 3.0624 - val_accuracy: 0.9585 - val_precision: 0.9622 - val_recall: 0.9550 - val_auc: 0.9970
# Epoch 7/30
# 200/200 [==============================] - 105s 522ms/step - loss: 3.0256 - accuracy: 0.9303 - precision: 0.9329 - recall: 0.9256 - auc: 0.9920 - val_loss: 2.8263 - val_accuracy: 0.9515 - val_precision: 0.9572 - val_recall: 0.9495 - val_auc: 0.9963
# Epoch 8/30
# 200/200 [==============================] - 105s 522ms/step - loss: 2.7449 - accuracy: 0.9447 - precision: 0.9468 - recall: 0.9394 - auc: 0.9936 - val_loss: 2.5768 - val_accuracy: 0.9605 - val_precision: 0.9628 - val_recall: 0.9570 - val_auc: 0.9971
# Epoch 9/30
# 200/200 [==============================] - 103s 515ms/step - loss: 2.5176 - accuracy: 0.9425 - precision: 0.9455 - recall: 0.9388 - auc: 0.9939 - val_loss: 2.3490 - val_accuracy: 0.9610 - val_precision: 0.9623 - val_recall: 0.9565 - val_auc: 0.9980
# Epoch 10/30
# 200/200 [==============================] - 103s 516ms/step - loss: 2.2937 - accuracy: 0.9463 - precision: 0.9507 - recall: 0.9453 - auc: 0.9943 - val_loss: 2.1511 - val_accuracy: 0.9595 - val_precision: 0.9608 - val_recall: 0.9565 - val_auc: 0.9971
# Epoch 11/30
# 200/200 [==============================] - 104s 520ms/step - loss: 2.1106 - accuracy: 0.9450 - precision: 0.9485 - recall: 0.9434 - auc: 0.9949 - val_loss: 1.9684 - val_accuracy: 0.9575 - val_precision: 0.9608 - val_recall: 0.9555 - val_auc: 0.9977
# Epoch 12/30
# 200/200 [==============================] - 104s 520ms/step - loss: 1.9239 - accuracy: 0.9469 - precision: 0.9492 - recall: 0.9450 - auc: 0.9950 - val_loss: 1.8047 - val_accuracy: 0.9590 - val_precision: 0.9618 - val_recall: 0.9555 - val_auc: 0.9976
# Epoch 13/30
# 200/200 [==============================] - 104s 519ms/step - loss: 1.7672 - accuracy: 0.9475 - precision: 0.9501 - recall: 0.9459 - auc: 0.9952 - val_loss: 1.6619 - val_accuracy: 0.9540 - val_precision: 0.9568 - val_recall: 0.9530 - val_auc: 0.9971
# Epoch 14/30
# 200/200 [==============================] - 103s 515ms/step - loss: 1.6199 - accuracy: 0.9525 - precision: 0.9548 - recall: 0.9500 - auc: 0.9945 - val_loss: 1.5198 - val_accuracy: 0.9595 - val_precision: 0.9628 - val_recall: 0.9580 - val_auc: 0.9973
# Epoch 15/30
# 200/200 [==============================] - 103s 512ms/step - loss: 1.4837 - accuracy: 0.9513 - precision: 0.9527 - recall: 0.9497 - auc: 0.9952 - val_loss: 1.3708 - val_accuracy: 0.9685 - val_precision: 0.9724 - val_recall: 0.9675 - val_auc: 0.9986
# Epoch 16/30
# 200/200 [==============================] - 104s 520ms/step - loss: 1.3557 - accuracy: 0.9544 - precision: 0.9560 - recall: 0.9516 - auc: 0.9961 - val_loss: 1.2758 - val_accuracy: 0.9620 - val_precision: 0.9638 - val_recall: 0.9585 - val_auc: 0.9978
# Epoch 17/30
# 200/200 [==============================] - 103s 515ms/step - loss: 1.2447 - accuracy: 0.9578 - precision: 0.9607 - recall: 0.9556 - auc: 0.9962 - val_loss: 1.1717 - val_accuracy: 0.9650 - val_precision: 0.9678 - val_recall: 0.9610 - val_auc: 0.9977
# Epoch 18/30
# 200/200 [==============================] - 103s 513ms/step - loss: 1.1586 - accuracy: 0.9534 - precision: 0.9572 - recall: 0.9509 - auc: 0.9955 - val_loss: 1.1047 - val_accuracy: 0.9505 - val_precision: 0.9533 - val_recall: 0.9485 - val_auc: 0.9969
# Epoch 19/30
# 200/200 [==============================] - 104s 519ms/step - loss: 1.0654 - accuracy: 0.9550 - precision: 0.9600 - recall: 0.9528 - auc: 0.9958 - val_loss: 0.9985 - val_accuracy: 0.9620 - val_precision: 0.9634 - val_recall: 0.9620 - val_auc: 0.9977
# Epoch 20/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.9897 - accuracy: 0.9531 - precision: 0.9564 - recall: 0.9519 - auc: 0.9962 - val_loss: 0.9183 - val_accuracy: 0.9655 - val_precision: 0.9679 - val_recall: 0.9640 - val_auc: 0.9979
# Epoch 21/30
# 200/200 [==============================] - 103s 517ms/step - loss: 0.9139 - accuracy: 0.9553 - precision: 0.9564 - recall: 0.9531 - auc: 0.9961 - val_loss: 0.8696 - val_accuracy: 0.9615 - val_precision: 0.9634 - val_recall: 0.9605 - val_auc: 0.9961
# Epoch 22/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.8497 - accuracy: 0.9588 - precision: 0.9605 - recall: 0.9572 - auc: 0.9955 - val_loss: 0.8353 - val_accuracy: 0.9505 - val_precision: 0.9547 - val_recall: 0.9480 - val_auc: 0.9959
# Epoch 23/30
# 200/200 [==============================] - 103s 516ms/step - loss: 0.7744 - accuracy: 0.9609 - precision: 0.9624 - recall: 0.9594 - auc: 0.9971 - val_loss: 0.7771 - val_accuracy: 0.9505 - val_precision: 0.9542 - val_recall: 0.9470 - val_auc: 0.9957
# Epoch 24/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.7213 - accuracy: 0.9566 - precision: 0.9598 - recall: 0.9547 - auc: 0.9974 - val_loss: 0.7001 - val_accuracy: 0.9640 - val_precision: 0.9658 - val_recall: 0.9610 - val_auc: 0.9969
# Epoch 25/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.6737 - accuracy: 0.9594 - precision: 0.9620 - recall: 0.9566 - auc: 0.9965 - val_loss: 0.6656 - val_accuracy: 0.9560 - val_precision: 0.9588 - val_recall: 0.9530 - val_auc: 0.9963
# Epoch 26/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.6246 - accuracy: 0.9609 - precision: 0.9630 - recall: 0.9584 - auc: 0.9975 - val_loss: 0.6174 - val_accuracy: 0.9580 - val_precision: 0.9589 - val_recall: 0.9565 - val_auc: 0.9964
# Epoch 27/30
# 200/200 [==============================] - 103s 514ms/step - loss: 0.5852 - accuracy: 0.9597 - precision: 0.9623 - recall: 0.9584 - auc: 0.9974 - val_loss: 0.5748 - val_accuracy: 0.9630 - val_precision: 0.9640 - val_recall: 0.9630 - val_auc: 0.9969
# Epoch 28/30
# 200/200 [==============================] - 103s 512ms/step - loss: 0.5542 - accuracy: 0.9625 - precision: 0.9646 - recall: 0.9609 - auc: 0.9968 - val_loss: 0.5708 - val_accuracy: 0.9525 - val_precision: 0.9543 - val_recall: 0.9495 - val_auc: 0.9953
# Epoch 29/30
# 200/200 [==============================] - 104s 521ms/step - loss: 0.5251 - accuracy: 0.9622 - precision: 0.9648 - recall: 0.9606 - auc: 0.9974 - val_loss: 0.4913 - val_accuracy: 0.9670 - val_precision: 0.9694 - val_recall: 0.9665 - val_auc: 0.9983
# Epoch 30/30
# 200/200 [==============================] - 102s 511ms/step - loss: 0.5048 - accuracy: 0.9578 - precision: 0.9607 - recall: 0.9556 - auc: 0.9970 - val_loss: 0.5280 - val_accuracy: 0.9420 - val_precision: 0.9448 - val_recall: 0.9415 - val_auc: 0.9954

# %% [markdown]
# # Model evaluation
# the trained model is evaluated on training, validation and test dataset

# %%
train_evaluation = model.evaluate(train_generator)
# Out:
# 200/200 [==============================] - 74s 370ms/step - loss: 0.4163 - accuracy: 0.9878 - precision: 0.9884 - recall: 0.9872 - auc: 0.9995

# %%
val_evaluation = model.evaluate(validation_generator)
# Out:
# 125/125 [==============================] - 29s 231ms/step - loss: 0.5280 - accuracy: 0.9420 - precision: 0.9448 - recall: 0.9415 - auc: 0.9954

# %%
test_evaluation = model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 19s 376ms/step - loss: 0.5266 - accuracy: 0.9438 - precision: 0.9461 - recall: 0.9438 - auc: 0.9943

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Obtain the true labels and predicted probabilities from the test generator
test_steps = test_generator.samples // test_generator.batch_size
y_test = []
y_score = []

for i in range(test_steps):
    x_batch, y_batch = next(test_generator)
    y_test.append(y_batch)
    y_score.append(model.predict(x_batch))

# Convert lists to arrays
y_test = np.concatenate(y_test)
y_score = np.concatenate(y_score)

# Convert labels to binary matrix
y_test_bin = label_binarize(y_test, classes=range(test_generator.num_classes))

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_test_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves with class names
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.4f})')

plt.plot(fpr["micro"], tpr["micro"],
         label=f'Micro-average (AUC = {roc_auc["micro"]:.4f})',
         linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', linewidth=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each Class')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Performance Plots
# the plots for the different classification metrics are plotted here

# %% [markdown]
#  **Learning curve**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %% [markdown]
# **Precision plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **Recall plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **AUC plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# # Model prediction
# In this part the trained model is used to predict the intestinal abnormalities present in the input image.

# %%
from keras.preprocessing import image
img = image.load_img('../input/curated-colon-dataset-for-deep-learning/test/0_normal/test_normal_ (1).jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"  

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))
# Out:
# [[9.9999797e-01 7.8978189e-07 1.6360784e-07 1.0084514e-06]]
# THE UPLOADED IMAGE SEEMS TO BE: Normal

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Reset the generator before predicting
test_generator.reset()

# Get the true labels and predicted probabilities from the model
true_labels = []
predicted_probs = []

# Iterate over the testing data to get predictions
for i in range(len(test_generator)):
    imgs, labels = next(test_generator)
    true_labels.extend(np.argmax(labels, axis=1))
    predicted_probs.extend(np.argmax(model.predict(imgs), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_probs)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# Print classification report
print(classification_report(true_labels, predicted_probs, target_names=list(test_generator.class_indices.keys())))
# Out:
#                       precision    recall  f1-score   support
#
#             0_normal       0.95      0.99      0.97       200
# 1_ulcerative_colitis       0.88      0.96      0.92       200
#             2_polyps       0.98      0.82      0.89       200
#        3_esophagitis       0.98      1.00      0.99       200
#
#             accuracy                           0.94       800
#            macro avg       0.95      0.94      0.94       800
#         weighted avg       0.95      0.94      0.94       800

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
