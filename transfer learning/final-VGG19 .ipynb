# %% [markdown]
# THE FOLLOWING STEPS ARE INVOLVED IN THE ENTIRE PROCESS OF IMAGE CLASSIFICATION
#
# 1.IMPORTING LIBRARIES
#
# 2.IMAGE PROCESSING
#
# 3.MODEL CREATION
#
# 4.MODEL COMPILATION
#
# 5.MODEL TRAINING
#
# 6.MODEL EVALUATION
#
# 7.MODEL PREDICTION

# %% [markdown]
# STEP 1-importing essential libraries
# tensorflow is a deep learning framework suitable for applications involving neural networks.
#
# using tensorflow we can build,train,evaluate and predict our neural network.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.metrics import roc_curve, auc
from itertools import cycle
from sklearn.preprocessing import label_binarize

# %% [markdown]
# # loading the dataset
# The training, testing and validation datasets are taken from the given dataset.

# %%
train_set='../input/curated-colon-dataset-for-deep-learning/train'
val_set='../input/curated-colon-dataset-for-deep-learning/val'
test_set='../input/curated-colon-dataset-for-deep-learning/test'

# %% [markdown]
# # STEP 2-image processing
# the imagedatagenerator is used to implement data augmentation. we can process the image as we want and create batches of image data.
#
# check this link for further details:- https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=20,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
validation_datagen = image.ImageDataGenerator()
test_datagen = image.ImageDataGenerator()

# %% [markdown]
# The images in digital world have pixels whose intensities range from 0 to 255 where black being 0 and white being 255.The rescaling of 1./255 allows it to convert to decimals values ranging from 0 to 1.
#
# the flow_from_directory allow us to use the images availabe in the google colab files section. the dataset contains images of variable size. hence it is essential to reshape them to (224,224). (the input dimensions for pretrained model)
#
# the batch size is an important parameter which can affect the training time and accuracy. less batch size increases accuracy and training time and vice versa. the batch size is taken as powers of two.

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    val_set,
    target_size=(224, 224),
    batch_size=16,
    shuffle=True,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'0_normal': 0, '1_ulcerative_colitis': 1, '2_polyps': 2, '3_esophagitis': 3}

# %% [markdown]
# # STEP 3-model creation
# we are using the pretrained cnn meaning that the cnn is already trained on the imagenet dataset and has the weights stored in it. we are going to customise the model by adding additional layers of our choice(remember more layers can increase parameters leading to overfitting).
#
# we are using the MobileNetV2 model for this application. this model was developed by google in 2017 and is known for its light memory. this model is ideal for devices with less RAM and processing power like microcomputers and mobiles.
#
# input_shape=(224,224,3) => this is the input dimensions of the model. this is the parameter mentioned in the processing part. the 3 refers to the three channels R,G,B
#
# we are training it partially so as to reduce the traning time on the stake of accuracy. (it is better to train model fully for better results)

# %% [markdown]
# > **NOTE- turn on the internet in the settings option in order to download the base model**

# %%
class CustomGaussianNoise(tf.keras.layers.GaussianNoise):
    def __init__(self, stddev, **kwargs):
        super(CustomGaussianNoise, self).__init__(stddev, **kwargs)

    def get_config(self):
        config = super().get_config()
        config.update({"stddev": self.stddev})
        return config
# Custom GaussianNoise layer with get_config method

# %%
base_model =tf.keras.applications.VGG16(weights='imagenet', input_shape=(224, 224, 3), include_top=False)

for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model)
model.add(CustomGaussianNoise(0.35))
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(CustomGaussianNoise(0.35))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# custom_gaussian_noise (Custo (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# custom_gaussian_noise_1 (Cus (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 14,848,068
# Trainable params: 132,868
# Non-trainable params: 14,715,200
# _________________________________________________________________

# %% [markdown]
# # Model Compilation
# The built neural network has to be compiled before training. It is compiled using a loss function, optimizer and metrics. Here, crossentropy loss function, adam optimizer and accuracy, precision, recall and AUC are the different metrics.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 'Precision', 'Recall', 'AUC'])

# %% [markdown]
# ** Callbacks**

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# %% [markdown]
# # Model Training

# %% [markdown]
# TIP- ensure that the gpu (Graphics Processing Unit) is used so as to boost the training speed.

# %%
# Train model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 139s 636ms/step - loss: 4.5064 - accuracy: 0.5650 - precision: 0.5977 - recall: 0.5122 - auc: 0.8030 - val_loss: 4.0320 - val_accuracy: 0.6630 - val_precision: 0.7109 - val_recall: 0.5915 - val_auc: 0.8788
# Epoch 2/30
# 200/200 [==============================] - 110s 550ms/step - loss: 3.6469 - accuracy: 0.7900 - precision: 0.8093 - recall: 0.7625 - auc: 0.9413 - val_loss: 3.6291 - val_accuracy: 0.7465 - val_precision: 0.7767 - val_recall: 0.7095 - val_auc: 0.9234
# Epoch 3/30
# 200/200 [==============================] - 112s 560ms/step - loss: 3.3041 - accuracy: 0.8331 - precision: 0.8479 - recall: 0.8134 - auc: 0.9626 - val_loss: 3.3047 - val_accuracy: 0.7995 - val_precision: 0.8221 - val_recall: 0.7740 - val_auc: 0.9459
# Epoch 4/30
# 200/200 [==============================] - 110s 548ms/step - loss: 3.0034 - accuracy: 0.8694 - precision: 0.8838 - recall: 0.8584 - auc: 0.9759 - val_loss: 3.0929 - val_accuracy: 0.7965 - val_precision: 0.8181 - val_recall: 0.7715 - val_auc: 0.9498
# Epoch 5/30
# 200/200 [==============================] - 103s 515ms/step - loss: 2.7514 - accuracy: 0.8984 - precision: 0.9071 - recall: 0.8884 - auc: 0.9832 - val_loss: 2.8400 - val_accuracy: 0.8330 - val_precision: 0.8512 - val_recall: 0.8125 - val_auc: 0.9621
# Epoch 6/30
# 200/200 [==============================] - 100s 501ms/step - loss: 2.5825 - accuracy: 0.9019 - precision: 0.9114 - recall: 0.8931 - auc: 0.9837 - val_loss: 2.6722 - val_accuracy: 0.8375 - val_precision: 0.8493 - val_recall: 0.8230 - val_auc: 0.9643
# Epoch 7/30
# 200/200 [==============================] - 100s 499ms/step - loss: 2.4205 - accuracy: 0.8963 - precision: 0.9030 - recall: 0.8900 - auc: 0.9847 - val_loss: 2.5444 - val_accuracy: 0.8280 - val_precision: 0.8442 - val_recall: 0.8180 - val_auc: 0.9632
# Epoch 8/30
# 200/200 [==============================] - 100s 501ms/step - loss: 2.2295 - accuracy: 0.9147 - precision: 0.9233 - recall: 0.9069 - auc: 0.9893 - val_loss: 2.3991 - val_accuracy: 0.8300 - val_precision: 0.8439 - val_recall: 0.8190 - val_auc: 0.9646
# Epoch 9/30
# 200/200 [==============================] - 100s 500ms/step - loss: 2.0734 - accuracy: 0.9269 - precision: 0.9341 - recall: 0.9209 - auc: 0.9918 - val_loss: 2.2701 - val_accuracy: 0.8340 - val_precision: 0.8461 - val_recall: 0.8245 - val_auc: 0.9658
# Epoch 10/30
# 200/200 [==============================] - 101s 507ms/step - loss: 1.9398 - accuracy: 0.9375 - precision: 0.9423 - recall: 0.9331 - auc: 0.9920 - val_loss: 2.2076 - val_accuracy: 0.8160 - val_precision: 0.8258 - val_recall: 0.8080 - val_auc: 0.9595
# Epoch 11/30
# 200/200 [==============================] - 100s 501ms/step - loss: 1.8554 - accuracy: 0.9269 - precision: 0.9305 - recall: 0.9209 - auc: 0.9909 - val_loss: 1.9943 - val_accuracy: 0.8510 - val_precision: 0.8598 - val_recall: 0.8405 - val_auc: 0.9736
# Epoch 12/30
# 200/200 [==============================] - 102s 511ms/step - loss: 1.7130 - accuracy: 0.9372 - precision: 0.9440 - recall: 0.9328 - auc: 0.9934 - val_loss: 1.9379 - val_accuracy: 0.8425 - val_precision: 0.8527 - val_recall: 0.8335 - val_auc: 0.9689
# Epoch 13/30
# 200/200 [==============================] - 103s 517ms/step - loss: 1.6336 - accuracy: 0.9344 - precision: 0.9391 - recall: 0.9303 - auc: 0.9926 - val_loss: 1.7866 - val_accuracy: 0.8575 - val_precision: 0.8690 - val_recall: 0.8490 - val_auc: 0.9756
# Epoch 14/30
# 200/200 [==============================] - 103s 517ms/step - loss: 1.5376 - accuracy: 0.9375 - precision: 0.9417 - recall: 0.9341 - auc: 0.9934 - val_loss: 1.6686 - val_accuracy: 0.8705 - val_precision: 0.8819 - val_recall: 0.8625 - val_auc: 0.9796
# Epoch 15/30
# 200/200 [==============================] - 107s 533ms/step - loss: 1.4458 - accuracy: 0.9375 - precision: 0.9399 - recall: 0.9341 - auc: 0.9942 - val_loss: 1.6617 - val_accuracy: 0.8450 - val_precision: 0.8498 - val_recall: 0.8345 - val_auc: 0.9718
# Epoch 16/30
# 200/200 [==============================] - 110s 549ms/step - loss: 1.3678 - accuracy: 0.9459 - precision: 0.9488 - recall: 0.9434 - auc: 0.9942 - val_loss: 1.5896 - val_accuracy: 0.8450 - val_precision: 0.8523 - val_recall: 0.8395 - val_auc: 0.9730
# Epoch 17/30
# 200/200 [==============================] - 100s 502ms/step - loss: 1.2916 - accuracy: 0.9491 - precision: 0.9522 - recall: 0.9469 - auc: 0.9939 - val_loss: 1.4732 - val_accuracy: 0.8615 - val_precision: 0.8688 - val_recall: 0.8540 - val_auc: 0.9779
# Epoch 18/30
# 200/200 [==============================] - 103s 514ms/step - loss: 1.2085 - accuracy: 0.9513 - precision: 0.9547 - recall: 0.9488 - auc: 0.9962 - val_loss: 1.3650 - val_accuracy: 0.8740 - val_precision: 0.8842 - val_recall: 0.8630 - val_auc: 0.9819
# Epoch 19/30
# 200/200 [==============================] - 100s 502ms/step - loss: 1.1775 - accuracy: 0.9400 - precision: 0.9430 - recall: 0.9366 - auc: 0.9944 - val_loss: 1.3317 - val_accuracy: 0.8765 - val_precision: 0.8861 - val_recall: 0.8670 - val_auc: 0.9800
# Epoch 20/30
# 200/200 [==============================] - 102s 508ms/step - loss: 1.1148 - accuracy: 0.9453 - precision: 0.9472 - recall: 0.9419 - auc: 0.9950 - val_loss: 1.3034 - val_accuracy: 0.8650 - val_precision: 0.8759 - val_recall: 0.8575 - val_auc: 0.9772
# Epoch 21/30
# 200/200 [==============================] - 107s 537ms/step - loss: 1.0576 - accuracy: 0.9428 - precision: 0.9449 - recall: 0.9375 - auc: 0.9954 - val_loss: 1.2552 - val_accuracy: 0.8670 - val_precision: 0.8740 - val_recall: 0.8605 - val_auc: 0.9779
# Epoch 22/30
# 200/200 [==============================] - 109s 545ms/step - loss: 1.0003 - accuracy: 0.9516 - precision: 0.9551 - recall: 0.9497 - auc: 0.9952 - val_loss: 1.1980 - val_accuracy: 0.8685 - val_precision: 0.8756 - val_recall: 0.8625 - val_auc: 0.9789
# Epoch 23/30
# 200/200 [==============================] - 113s 567ms/step - loss: 0.9499 - accuracy: 0.9531 - precision: 0.9551 - recall: 0.9509 - auc: 0.9955 - val_loss: 1.1857 - val_accuracy: 0.8625 - val_precision: 0.8695 - val_recall: 0.8565 - val_auc: 0.9761
# Epoch 24/30
# 200/200 [==============================] - 105s 524ms/step - loss: 0.9189 - accuracy: 0.9525 - precision: 0.9571 - recall: 0.9481 - auc: 0.9949 - val_loss: 1.0537 - val_accuracy: 0.8850 - val_precision: 0.8915 - val_recall: 0.8795 - val_auc: 0.9842
# Epoch 25/30
# 200/200 [==============================] - 101s 504ms/step - loss: 0.8588 - accuracy: 0.9522 - precision: 0.9545 - recall: 0.9503 - auc: 0.9966 - val_loss: 1.0061 - val_accuracy: 0.8915 - val_precision: 0.8963 - val_recall: 0.8855 - val_auc: 0.9852
# Epoch 26/30
# 200/200 [==============================] - 103s 516ms/step - loss: 0.8393 - accuracy: 0.9466 - precision: 0.9501 - recall: 0.9456 - auc: 0.9954 - val_loss: 1.0010 - val_accuracy: 0.8800 - val_precision: 0.8842 - val_recall: 0.8740 - val_auc: 0.9820
# Epoch 27/30
# 200/200 [==============================] - 101s 507ms/step - loss: 0.8037 - accuracy: 0.9519 - precision: 0.9545 - recall: 0.9500 - auc: 0.9952 - val_loss: 0.9911 - val_accuracy: 0.8675 - val_precision: 0.8797 - val_recall: 0.8630 - val_auc: 0.9805
# Epoch 28/30
# 200/200 [==============================] - 101s 505ms/step - loss: 0.7533 - accuracy: 0.9578 - precision: 0.9610 - recall: 0.9559 - auc: 0.9962 - val_loss: 0.8966 - val_accuracy: 0.8970 - val_precision: 0.9015 - val_recall: 0.8920 - val_auc: 0.9859
# Epoch 29/30
# 200/200 [==============================] - 102s 508ms/step - loss: 0.7420 - accuracy: 0.9453 - precision: 0.9503 - recall: 0.9438 - auc: 0.9956 - val_loss: 0.8786 - val_accuracy: 0.8895 - val_precision: 0.8976 - val_recall: 0.8850 - val_auc: 0.9848
# Epoch 30/30
# 200/200 [==============================] - 101s 504ms/step - loss: 0.6980 - accuracy: 0.9531 - precision: 0.9554 - recall: 0.9503 - auc: 0.9963 - val_loss: 0.8382 - val_accuracy: 0.8960 - val_precision: 0.8989 - val_recall: 0.8935 - val_auc: 0.9860

# %% [markdown]
# # Model evaluation
# the trained model is evaluated on training, validation and test dataset

# %%
train_evaluation = model.evaluate(train_generator)
# Out:
# 200/200 [==============================] - 75s 375ms/step - loss: 0.6031 - accuracy: 0.9828 - precision: 0.9828 - recall: 0.9816 - auc: 0.9996

# %%
val_evaluation = model.evaluate(validation_generator)
# Out:
# 125/125 [==============================] - 29s 233ms/step - loss: 0.8382 - accuracy: 0.8960 - precision: 0.8989 - recall: 0.8935 - auc: 0.9860

# %%
test_evaluation = model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 12s 234ms/step - loss: 0.7944 - accuracy: 0.9038 - precision: 0.9057 - recall: 0.9000 - auc: 0.9897

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Obtain the true labels and predicted probabilities from the test generator
test_steps = test_generator.samples // test_generator.batch_size
y_test = []
y_score = []

for i in range(test_steps):
    x_batch, y_batch = next(test_generator)
    y_test.append(y_batch)
    y_score.append(model.predict(x_batch))

# Convert lists to arrays
y_test = np.concatenate(y_test)
y_score = np.concatenate(y_score)

# Convert labels to binary matrix
y_test_bin = label_binarize(y_test, classes=range(test_generator.num_classes))

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_test_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves with class names
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.4f})')

plt.plot(fpr["micro"], tpr["micro"],
         label=f'Micro-average (AUC = {roc_auc["micro"]:.4f})',
         linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', linewidth=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each Class')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Performance Plots
# the plots for the different classification metrics are plotted here

# %% [markdown]
#  **Learning curve**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %% [markdown]
# **Precision plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **Recall plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **AUC plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# # Model prediction
# In this part the trained model is used to predict the intestinal abnormalities present in the input image.

# %%
from keras.preprocessing import image
img = image.load_img('../input/curated-colon-dataset-for-deep-learning/test/0_normal/test_normal_ (1).jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"  

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))
# Out:
# [[9.9998784e-01 4.6516989e-06 1.8682711e-06 5.6103618e-06]]
# THE UPLOADED IMAGE SEEMS TO BE: Normal

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Reset the generator before predicting
test_generator.reset()

# Get the true labels and predicted probabilities from the model
true_labels = []
predicted_probs = []

# Iterate over the testing data to get predictions
for i in range(len(test_generator)):
    imgs, labels = next(test_generator)
    true_labels.extend(np.argmax(labels, axis=1))
    predicted_probs.extend(np.argmax(model.predict(imgs), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_probs)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# Print classification report
print(classification_report(true_labels, predicted_probs, target_names=list(test_generator.class_indices.keys())))
# Out:
#                       precision    recall  f1-score   support
#
#             0_normal       0.84      1.00      0.91       200
# 1_ulcerative_colitis       0.93      0.83      0.88       200
#             2_polyps       0.88      0.81      0.84       200
#        3_esophagitis       0.99      0.97      0.98       200
#
#             accuracy                           0.90       800
#            macro avg       0.91      0.90      0.90       800
#         weighted avg       0.91      0.90      0.90       800

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
