# %% [markdown]
# THE FOLLOWING STEPS ARE INVOLVED IN THE ENTIRE PROCESS OF IMAGE CLASSIFICATION
#
# 1.IMPORTING LIBRARIES
#
# 2.IMAGE PROCESSING
#
# 3.MODEL CREATION
#
# 4.MODEL COMPILATION
#
# 5.MODEL TRAINING
#
# 6.MODEL EVALUATION
#
# 7.MODEL PREDICTION

# %% [markdown]
# STEP 1-importing essential libraries
# tensorflow is a deep learning framework suitable for applications involving neural networks.
#
# using tensorflow we can build,train,evaluate and predict our neural network.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.metrics import roc_curve, auc
from itertools import cycle
from sklearn.preprocessing import label_binarize

# %% [markdown]
# # loading the dataset
# The training, testing and validation datasets are taken from the given dataset.

# %%
train_set='../input/curated-colon-dataset-for-deep-learning/train'
val_set='../input/curated-colon-dataset-for-deep-learning/val'
test_set='../input/curated-colon-dataset-for-deep-learning/test'

# %% [markdown]
# # STEP 2-image processing
# the imagedatagenerator is used to implement data augmentation. we can process the image as we want and create batches of image data.
#
# check this link for further details:- https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=20,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
validation_datagen = image.ImageDataGenerator()
test_datagen = image.ImageDataGenerator()

# %% [markdown]
# The images in digital world have pixels whose intensities range from 0 to 255 where black being 0 and white being 255.The rescaling of 1./255 allows it to convert to decimals values ranging from 0 to 1.
#
# the flow_from_directory allow us to use the images availabe in the google colab files section. the dataset contains images of variable size. hence it is essential to reshape them to (224,224). (the input dimensions for pretrained model)
#
# the batch size is an important parameter which can affect the training time and accuracy. less batch size increases accuracy and training time and vice versa. the batch size is taken as powers of two.

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    val_set,
    target_size=(224, 224),
    batch_size=16,
    shuffle=True,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'0_normal': 0, '1_ulcerative_colitis': 1, '2_polyps': 2, '3_esophagitis': 3}

# %% [markdown]
# # STEP 3-model creation
# we are using the pretrained cnn meaning that the cnn is already trained on the imagenet dataset and has the weights stored in it. we are going to customise the model by adding additional layers of our choice(remember more layers can increase parameters leading to overfitting).
#
# we are using the MobileNetV2 model for this application. this model was developed by google in 2017 and is known for its light memory. this model is ideal for devices with less RAM and processing power like microcomputers and mobiles.
#
# input_shape=(224,224,3) => this is the input dimensions of the model. this is the parameter mentioned in the processing part. the 3 refers to the three channels R,G,B
#
# we are training it partially so as to reduce the traning time on the stake of accuracy. (it is better to train model fully for better results)

# %% [markdown]
# > **NOTE- turn on the internet in the settings option in order to download the base model**

# %%
class CustomGaussianNoise(tf.keras.layers.GaussianNoise):
    def __init__(self, stddev, **kwargs):
        super(CustomGaussianNoise, self).__init__(stddev, **kwargs)

    def get_config(self):
        config = super().get_config()
        config.update({"stddev": self.stddev})
        return config
# Custom GaussianNoise layer with get_config method

# %%
base_model =tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224, 224, 3), include_top=False)

for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model)
model.add(CustomGaussianNoise(0.35))
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(CustomGaussianNoise(0.35))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 1s 0us/step
# 31801344/31790344 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb2 (Functional)  (None, 7, 7, 1408)        7768569
# _________________________________________________________________
# custom_gaussian_noise_2 (Cus (None, 7, 7, 1408)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1408)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               360704
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# custom_gaussian_noise_3 (Cus (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 8,131,325
# Trainable params: 362,244
# Non-trainable params: 7,769,081
# _________________________________________________________________

# %% [markdown]
# # Model Compilation
# The built neural network has to be compiled before training. It is compiled using a loss function, optimizer and metrics. Here, crossentropy loss function, adam optimizer and accuracy, precision, recall and AUC are the different metrics.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 'Precision', 'Recall', 'AUC'])

# %% [markdown]
# ** Callbacks**

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# %% [markdown]
# # Model Training

# %% [markdown]
# TIP- ensure that the gpu (Graphics Processing Unit) is used so as to boost the training speed.

# %%
# Train model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 113s 524ms/step - loss: 5.0511 - accuracy: 0.7159 - precision: 0.7489 - recall: 0.6831 - auc: 0.9068 - val_loss: 4.4387 - val_accuracy: 0.8955 - val_precision: 0.9344 - val_recall: 0.8470 - val_auc: 0.9862
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/30
# 200/200 [==============================] - 99s 493ms/step - loss: 4.3555 - accuracy: 0.8650 - precision: 0.8780 - recall: 0.8522 - auc: 0.9734 - val_loss: 4.0471 - val_accuracy: 0.9140 - val_precision: 0.9238 - val_recall: 0.9030 - val_auc: 0.9909
# Epoch 3/30
# 200/200 [==============================] - 98s 490ms/step - loss: 3.9495 - accuracy: 0.9050 - precision: 0.9126 - recall: 0.8969 - auc: 0.9860 - val_loss: 3.7627 - val_accuracy: 0.9100 - val_precision: 0.9162 - val_recall: 0.9020 - val_auc: 0.9902
# Epoch 4/30
# 200/200 [==============================] - 98s 492ms/step - loss: 3.6389 - accuracy: 0.9119 - precision: 0.9198 - recall: 0.9066 - auc: 0.9874 - val_loss: 3.4311 - val_accuracy: 0.9280 - val_precision: 0.9372 - val_recall: 0.9250 - val_auc: 0.9939
# Epoch 5/30
# 200/200 [==============================] - 99s 497ms/step - loss: 3.3301 - accuracy: 0.9266 - precision: 0.9309 - recall: 0.9216 - auc: 0.9904 - val_loss: 3.1637 - val_accuracy: 0.9275 - val_precision: 0.9348 - val_recall: 0.9245 - val_auc: 0.9939
# Epoch 6/30
# 200/200 [==============================] - 98s 492ms/step - loss: 3.0363 - accuracy: 0.9366 - precision: 0.9419 - recall: 0.9328 - auc: 0.9929 - val_loss: 2.9085 - val_accuracy: 0.9320 - val_precision: 0.9381 - val_recall: 0.9250 - val_auc: 0.9944
# Epoch 7/30
# 200/200 [==============================] - 98s 488ms/step - loss: 2.8085 - accuracy: 0.9341 - precision: 0.9384 - recall: 0.9281 - auc: 0.9917 - val_loss: 2.6667 - val_accuracy: 0.9375 - val_precision: 0.9427 - val_recall: 0.9290 - val_auc: 0.9947
# Epoch 8/30
# 200/200 [==============================] - 98s 491ms/step - loss: 2.5712 - accuracy: 0.9419 - precision: 0.9473 - recall: 0.9378 - auc: 0.9924 - val_loss: 2.4224 - val_accuracy: 0.9480 - val_precision: 0.9512 - val_recall: 0.9450 - val_auc: 0.9962
# Epoch 9/30
# 200/200 [==============================] - 98s 491ms/step - loss: 2.3348 - accuracy: 0.9481 - precision: 0.9519 - recall: 0.9459 - auc: 0.9953 - val_loss: 2.1989 - val_accuracy: 0.9595 - val_precision: 0.9623 - val_recall: 0.9570 - val_auc: 0.9976
# Epoch 10/30
# 200/200 [==============================] - 98s 491ms/step - loss: 2.1431 - accuracy: 0.9463 - precision: 0.9508 - recall: 0.9425 - auc: 0.9953 - val_loss: 2.0636 - val_accuracy: 0.9415 - val_precision: 0.9451 - val_recall: 0.9390 - val_auc: 0.9953
# Epoch 11/30
# 200/200 [==============================] - 99s 494ms/step - loss: 1.9810 - accuracy: 0.9494 - precision: 0.9516 - recall: 0.9466 - auc: 0.9941 - val_loss: 1.8798 - val_accuracy: 0.9535 - val_precision: 0.9543 - val_recall: 0.9510 - val_auc: 0.9964
# Epoch 12/30
# 200/200 [==============================] - 99s 493ms/step - loss: 1.7983 - accuracy: 0.9559 - precision: 0.9580 - recall: 0.9544 - auc: 0.9961 - val_loss: 1.7348 - val_accuracy: 0.9505 - val_precision: 0.9513 - val_recall: 0.9480 - val_auc: 0.9959
# Epoch 13/30
# 200/200 [==============================] - 99s 497ms/step - loss: 1.6606 - accuracy: 0.9572 - precision: 0.9589 - recall: 0.9544 - auc: 0.9958 - val_loss: 1.5716 - val_accuracy: 0.9605 - val_precision: 0.9619 - val_recall: 0.9600 - val_auc: 0.9973
# Epoch 14/30
# 200/200 [==============================] - 98s 491ms/step - loss: 1.5238 - accuracy: 0.9572 - precision: 0.9610 - recall: 0.9538 - auc: 0.9962 - val_loss: 1.4832 - val_accuracy: 0.9520 - val_precision: 0.9523 - val_recall: 0.9485 - val_auc: 0.9955
# Epoch 15/30
# 200/200 [==============================] - 98s 490ms/step - loss: 1.3937 - accuracy: 0.9634 - precision: 0.9652 - recall: 0.9616 - auc: 0.9970 - val_loss: 1.3570 - val_accuracy: 0.9535 - val_precision: 0.9539 - val_recall: 0.9510 - val_auc: 0.9958
# Epoch 16/30
# 200/200 [==============================] - 98s 490ms/step - loss: 1.2812 - accuracy: 0.9641 - precision: 0.9680 - recall: 0.9638 - auc: 0.9972 - val_loss: 1.2469 - val_accuracy: 0.9555 - val_precision: 0.9574 - val_recall: 0.9540 - val_auc: 0.9964
# Epoch 17/30
# 200/200 [==============================] - 98s 493ms/step - loss: 1.1910 - accuracy: 0.9600 - precision: 0.9621 - recall: 0.9591 - auc: 0.9970 - val_loss: 1.1519 - val_accuracy: 0.9550 - val_precision: 0.9567 - val_recall: 0.9510 - val_auc: 0.9966
# Epoch 18/30
# 200/200 [==============================] - 98s 492ms/step - loss: 1.1083 - accuracy: 0.9566 - precision: 0.9583 - recall: 0.9541 - auc: 0.9973 - val_loss: 1.0991 - val_accuracy: 0.9495 - val_precision: 0.9499 - val_recall: 0.9475 - val_auc: 0.9945
# Epoch 19/30
# 200/200 [==============================] - 99s 495ms/step - loss: 1.0349 - accuracy: 0.9578 - precision: 0.9595 - recall: 0.9563 - auc: 0.9964 - val_loss: 0.9990 - val_accuracy: 0.9580 - val_precision: 0.9613 - val_recall: 0.9565 - val_auc: 0.9969
# Epoch 20/30
# 200/200 [==============================] - 98s 490ms/step - loss: 0.9544 - accuracy: 0.9613 - precision: 0.9621 - recall: 0.9600 - auc: 0.9970 - val_loss: 0.9398 - val_accuracy: 0.9530 - val_precision: 0.9544 - val_recall: 0.9515 - val_auc: 0.9964
# Epoch 21/30
# 200/200 [==============================] - 98s 491ms/step - loss: 0.8879 - accuracy: 0.9628 - precision: 0.9648 - recall: 0.9603 - auc: 0.9972 - val_loss: 0.8898 - val_accuracy: 0.9450 - val_precision: 0.9478 - val_recall: 0.9435 - val_auc: 0.9957
# Epoch 22/30
# 200/200 [==============================] - 98s 490ms/step - loss: 0.8217 - accuracy: 0.9653 - precision: 0.9656 - recall: 0.9641 - auc: 0.9974 - val_loss: 0.7898 - val_accuracy: 0.9665 - val_precision: 0.9679 - val_recall: 0.9655 - val_auc: 0.9973
# Epoch 23/30
# 200/200 [==============================] - 99s 493ms/step - loss: 0.7750 - accuracy: 0.9613 - precision: 0.9639 - recall: 0.9591 - auc: 0.9972 - val_loss: 0.7697 - val_accuracy: 0.9570 - val_precision: 0.9589 - val_recall: 0.9555 - val_auc: 0.9966
# Epoch 24/30
# 200/200 [==============================] - 98s 492ms/step - loss: 0.7377 - accuracy: 0.9638 - precision: 0.9661 - recall: 0.9606 - auc: 0.9971 - val_loss: 0.6997 - val_accuracy: 0.9660 - val_precision: 0.9660 - val_recall: 0.9650 - val_auc: 0.9977
# Epoch 25/30
# 200/200 [==============================] - 98s 491ms/step - loss: 0.6750 - accuracy: 0.9684 - precision: 0.9693 - recall: 0.9669 - auc: 0.9981 - val_loss: 0.6633 - val_accuracy: 0.9660 - val_precision: 0.9684 - val_recall: 0.9655 - val_auc: 0.9969
# Epoch 26/30
# 200/200 [==============================] - 98s 491ms/step - loss: 0.6296 - accuracy: 0.9709 - precision: 0.9727 - recall: 0.9694 - auc: 0.9977 - val_loss: 0.6100 - val_accuracy: 0.9700 - val_precision: 0.9729 - val_recall: 0.9690 - val_auc: 0.9976
# Epoch 27/30
# 200/200 [==============================] - 97s 488ms/step - loss: 0.5979 - accuracy: 0.9688 - precision: 0.9711 - recall: 0.9672 - auc: 0.9979 - val_loss: 0.5909 - val_accuracy: 0.9660 - val_precision: 0.9684 - val_recall: 0.9645 - val_auc: 0.9972
# Epoch 28/30
# 200/200 [==============================] - 98s 488ms/step - loss: 0.5704 - accuracy: 0.9691 - precision: 0.9706 - recall: 0.9681 - auc: 0.9975 - val_loss: 0.5857 - val_accuracy: 0.9585 - val_precision: 0.9633 - val_recall: 0.9575 - val_auc: 0.9956
# Epoch 29/30
# 200/200 [==============================] - 98s 489ms/step - loss: 0.5321 - accuracy: 0.9691 - precision: 0.9702 - recall: 0.9675 - auc: 0.9983 - val_loss: 0.5698 - val_accuracy: 0.9540 - val_precision: 0.9582 - val_recall: 0.9515 - val_auc: 0.9950
# Epoch 30/30
# 200/200 [==============================] - 98s 491ms/step - loss: 0.5050 - accuracy: 0.9731 - precision: 0.9759 - recall: 0.9725 - auc: 0.9973 - val_loss: 0.4850 - val_accuracy: 0.9725 - val_precision: 0.9734 - val_recall: 0.9715 - val_auc: 0.9982

# %% [markdown]
# # Model evaluation
# the trained model is evaluated on training, validation and test dataset

# %%
train_evaluation = model.evaluate(train_generator)
# Out:
# 200/200 [==============================] - 71s 353ms/step - loss: 0.4245 - accuracy: 0.9922 - precision: 0.9922 - recall: 0.9922 - auc: 0.9997

# %%
val_evaluation = model.evaluate(validation_generator)
# Out:
# 125/125 [==============================] - 27s 218ms/step - loss: 0.4850 - accuracy: 0.9725 - precision: 0.9734 - recall: 0.9715 - auc: 0.9982

# %%
test_evaluation = model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 12s 231ms/step - loss: 0.4577 - accuracy: 0.9775 - precision: 0.9799 - recall: 0.9762 - auc: 0.9994

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Obtain the true labels and predicted probabilities from the test generator
test_steps = test_generator.samples // test_generator.batch_size
y_test = []
y_score = []

for i in range(test_steps):
    x_batch, y_batch = next(test_generator)
    y_test.append(y_batch)
    y_score.append(model.predict(x_batch))

# Convert lists to arrays
y_test = np.concatenate(y_test)
y_score = np.concatenate(y_score)

# Convert labels to binary matrix
y_test_bin = label_binarize(y_test, classes=range(test_generator.num_classes))

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_test_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves with class names
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.4f})')

plt.plot(fpr["micro"], tpr["micro"],
         label=f'Micro-average (AUC = {roc_auc["micro"]:.4f})',
         linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', linewidth=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each Class')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Performance Plots
# the plots for the different classification metrics are plotted here

# %% [markdown]
#  **Learning curve**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %% [markdown]
# **Precision plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **Recall plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# **AUC plot**

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %% [markdown]
# # Model prediction
# In this part the trained model is used to predict the intestinal abnormalities present in the input image.

# %%
from keras.preprocessing import image
img = image.load_img('../input/curated-colon-dataset-for-deep-learning/test/0_normal/test_normal_ (1).jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"  

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))
# Out:
# [[9.9994838e-01 4.9682261e-05 1.3171891e-06 5.6716522e-07]]
# THE UPLOADED IMAGE SEEMS TO BE: Normal

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Reset the generator before predicting
test_generator.reset()

# Get the true labels and predicted probabilities from the model
true_labels = []
predicted_probs = []

# Iterate over the testing data to get predictions
for i in range(len(test_generator)):
    imgs, labels = next(test_generator)
    true_labels.extend(np.argmax(labels, axis=1))
    predicted_probs.extend(np.argmax(model.predict(imgs), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_probs)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# Print classification report
print(classification_report(true_labels, predicted_probs, target_names=list(test_generator.class_indices.keys())))
# Out:
#                       precision    recall  f1-score   support
#
#             0_normal       1.00      1.00      1.00       200
# 1_ulcerative_colitis       0.98      0.93      0.96       200
#             2_polyps       0.95      0.98      0.96       200
#        3_esophagitis       0.99      1.00      0.99       200
#
#             accuracy                           0.98       800
#            macro avg       0.98      0.98      0.98       800
#         weighted avg       0.98      0.98      0.98       800

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
